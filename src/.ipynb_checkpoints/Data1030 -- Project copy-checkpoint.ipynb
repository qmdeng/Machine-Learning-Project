# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pylab as plt
from matplotlib import rc
import seaborn as sns
from sklearn.feature_selection import f_regression, mutual_info_regression 

df=pd.read_csv('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/data/OnlineNewsPopularity.csv', sep=', ')
df=df.drop(['url'], axis=1)
df=df.drop(['timedelta'],axis=1)
df.head()
# Out:
# /var/folders/pv/h923lk3s0nj8fscmw56yh3980000gn/T/ipykernel_26447/1913201444.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/data/OnlineNewsPopularity.csv', sep=', ')
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# ...

# %% [markdown]
# # Part I: EDA

# %%
#number of rows and cols
rows = len(df.axes[0])
columns = len(df.axes[1])
print('Number of rows: ' + str(rows))
print('Number of cols: ' + str(columns))
# Out:
# Number of rows: 39644
# Number of cols: 59

# %%
#datatype of each column
pd.set_option('display.max_rows', None)
df.dtypes
# Out:
# n_tokens_title                   float64
# n_tokens_content                 float64
# n_unique_tokens                  float64
# n_non_stop_words                 float64
# n_non_stop_unique_tokens         float64
# num_hrefs                        float64
# num_self_hrefs                   float64
# num_imgs                         float64
# num_videos                       float64
# average_token_length             float64
# num_keywords                     float64
# data_channel_is_lifestyle        float64
# data_channel_is_entertainment    float64
# data_channel_is_bus              float64
# data_channel_is_socmed           float64
# data_channel_is_tech             float64
# data_channel_is_world            float64
# kw_min_min                       float64
# kw_max_min                       float64
# kw_avg_min                       float64
# kw_min_max                       float64
# kw_max_max                       float64
# kw_avg_max                       float64
# ...

# %% [markdown]
# The target variable we want to measure here is whether the online news is popular or not. Since the variable 'share' is a continuous data point, we need to caculate its percentail and then decide the specific value for the categories.

# %%
#The target varible is popularity of shares
df['shares'].describe()
# Out:
# count     39644.000000
# mean       3395.380184
# std       11626.950749
# min           1.000000
# 25%         946.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name: shares, dtype: float64

# %% [markdown]
# From the data shown above, we could pick different percentiles for classifying the popularity extent.
# 1st category ('0: poor') to be values equal to or smaller than 946 (0%-25% percentile)
# 2nd category ('1: average') to be values between 946 and 1400 (25%-50% percentile)
# 3rd category ('2: average') to be values between 1401 and 2800 (50%-75% percentile)
# 4nd category ('3: excellent') to be values larger than 2800 (75%-100% percentile)

# %%
#establish categories for our target variable
df['shares'] = np.where(df['shares'] <=1400, 0, df['shares'])
df['shares'] = np.where((df['shares'] > 1400), 1, df['shares'])
df.head(10)
# Out:
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
# 5            10.0             370.0         0.559889               1.0
# 6             8.0             960.0         0.418163               1.0
# 7            12.0             989.0         0.433574               1.0
# 8            11.0              97.0         0.670103               1.0
# 9            10.0             231.0         0.636364               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  num_videos  \
# 0                  0.815385        4.0             2.0       1.0         0.0
# ...

# %%
#visualize the target variable in histogram
plt.rcParams["figure.figsize"] = (4,3)
pd.value_counts(df['shares']).sort_index().plot.bar(color = ['lightblue'])
plt.xticks(rotation = 360,size=11)
plt.yticks(size=11)
plt.xlabel('number of shares',size=11)
plt.ylabel('counts',size=11)
txt = "This figure shows a distribution of target variables"
plt.figtext(0.5, -0.11, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/population.png', format='png', bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# Summary of the target variable:
# From the histogram, we can easily tell that the distribution of the target variable is mostly equally distributed, which does not have any skewness.

# %%
#plot the correlation graph
corr = df.corr()
plt.figure(figsize=(50,50))
sns.heatmap(corr,cbar=True,square=True,fmt='.1f',annot=True,cmap='Blues')
plt.xticks(size=11)
plt.yticks(size=11)
txt = "This figure shows correlation between variables"
plt.figtext(0.5, 0.1, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/correltion.png', format='png', bbox_inches="tight", dpi=300)

# %%
#caculate the correlation coefficient from each feature
corr_matrix=df.corr()
corr_matrix.head(100)
# Out:
#                                n_tokens_title  n_tokens_content  \
# n_tokens_title                       1.000000          0.018160
# n_tokens_content                     0.018160          1.000000
# n_unique_tokens                     -0.005318         -0.004737
# n_non_stop_words                    -0.004754          0.017512
# n_non_stop_unique_tokens            -0.005420          0.000373
# num_hrefs                           -0.053496          0.423065
# num_self_hrefs                      -0.014856          0.304682
# num_imgs                            -0.008858          0.342600
# num_videos                           0.051460          0.103699
# average_token_length                -0.071403          0.167789
# num_keywords                        -0.006077          0.072845
# data_channel_is_lifestyle           -0.070815          0.037548
# data_channel_is_entertainment        0.132791          0.060200
# data_channel_is_bus                 -0.023902         -0.006105
# ...

# %%
# Find features with correlation greater than 0.95
corr_abs = df.corr().abs()
high_corr_var=np.where(corr_abs>0.9)
high_corr_var=[(corr_abs.columns[x],corr_abs.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
print(high_corr_var)
# Out:
# [('n_unique_tokens', 'n_non_stop_words'), ('n_unique_tokens', 'n_non_stop_unique_tokens'), ('n_non_stop_words', 'n_non_stop_unique_tokens'), ('kw_max_min', 'kw_avg_min')]

# %% [markdown]
# As we could tell from the graphs and list above, there are three features ('n_unique_tokens', 'n_non_stop_unique_tokens', 'n_non_stop_words') that have extremely strong correlation with each other(coeffiecnt stronger than 0.95), so we need to drop two of those features and just leave one. Here I will just leave feature 'n_unique_tokens' and drop the rest two.

# %%
#drop features that are extremely correlated with other features
df=df.drop(['n_non_stop_words'], axis=1)
df=df.drop(['n_non_stop_unique_tokens'], axis=1)
df=df.drop(['kw_max_min'], axis=1)
df.shape
# Out:
# (39644, 56)

# %%
#find the most 5 correlated feature(absoulte value) with target varibale
corr_matrix=df.corr()
corr1 = corr_matrix["shares"].abs().sort_values(ascending=False)
corr = corr1.loc[corr1 != 1]
df_corr=pd.DataFrame(corr)
df_corr5=df_corr.head(5)
df_corr5
# Out:
#                                  shares
# kw_avg_avg                     0.162057
# LDA_02                         0.156471
# data_channel_is_world          0.150726
# is_weekend                     0.137616
# data_channel_is_entertainment  0.110558

# %%
#plot the five strongest correlation coefficient value with target variable
plt.figure(figsize=(9,4))
plt.rcParams['figure.facecolor'] = 'white'
plt.bar(df_corr5.index, df_corr5['shares'],color = ['wheat'])
txt = "This figure shows the five strongest correlation coefficient absolute values with target variable"
plt.figtext(0.5, -0.03, txt, ha='center', size=11)
plt.xticks(size=11)
plt.yticks(size=11)
plt.xlabel('feature',size=11)
plt.ylabel('correlation coefficient values',size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/corr.png', format='png', bbox_inches="tight", dpi=300)
plt.show()

# %%
# 1. Violinplot for shares vs kw_avg_avg
plt.rcParams["figure.figsize"] = (4,3)
plt.rcParams['axes.facecolor'] = 'white'
dataset = [df[df['shares']==0]['kw_avg_avg'].values,
           df[df['shares']==1]['kw_avg_avg'].values]

plt.violinplot(dataset = dataset)
plt.xticks([1,2,3,4],['0','1','2','3'],size=11)
plt.yticks(size=11)
plt.xlabel('popularity groups',size=11)
plt.ylabel('average keyword(avg shares)',size=11)
plt.semilogy()
txt = "This figure shows a correlation between number of shares and average keyword in avg share."
plt.figtext(0.5, -0.11, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/kw_avg_avg.png', format='png', bbox_inches="tight", dpi=300)
plt.show()

# %%
# 2. Boxplot for shares vs LDA_02
plt.rcParams["figure.figsize"] = (4,3)
plt.rcParams['axes.facecolor'] = 'white'
sns.boxplot(data=df, x='shares', y='LDA_02',palette = "RdBu")
plt.xlabel('number of shares',size=11)
plt.ylabel('Closeness to LDA topic 2',size=11)
plt.xticks(size=11)
plt.yticks(size=11)
plt.semilogy()
txt = "This figure shows a correlation between number of shares and closeness to LDA topic 2"
plt.figtext(0.5, -0.11, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/LDA_02.png', format='png', bbox_inches="tight", dpi=300)
plt.show()

# %%
#3. bar plot for shares vs is_weekend
plt.rcParams['axes.facecolor'] = 'white'
sns.catplot(
    data=df, x="shares", hue="is_weekend", kind="count",
    palette="pastel", edgecolor=".6", height=3.5)
# plt.rcParams["figure.figsize"] = (2,1)
# plt.figure(figsize=(4, 3))
plt.xlabel('number of shares',size=11)
plt.ylabel('counts',size=11)
plt.xticks(size=11)
plt.yticks(size=11)
txt = "This figure shows a correlation between number of shares and weekend"
plt.figtext(0.5, -0.03, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/is_weekend.png', format='png', bbox_inches="tight", dpi=300)

# %%
#4. bar plot for shares vs data_channel_is_world
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams["figure.figsize"] = (4,3)
sns.catplot(
    data=df, x="shares", hue="data_channel_is_world", kind="count",
    palette="pastel", edgecolor=".6",height = 3.5)
plt.xlabel('number of shares',size=11)
plt.ylabel('counts',size=11)
plt.xticks(size=11)
plt.yticks(size=11)
txt = "This figure shows a correlation between number of shares and article channel(world)"
plt.figtext(0.5, -0.03, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/world_channel.png', format='png', bbox_inches="tight", dpi=300)

# %%
#5: stacked bar plot for popularity groups vs data_channel_is_socmed
plt.rcParams["figure.figsize"] = (4,3)
plt.rcParams['figure.facecolor'] = 'white'
count_matrix = df.groupby(['data_channel_is_socmed', 'shares']).size().unstack()
count_matrix.plot(kind='bar', stacked=True)
plt.ylabel('counts',size=11)
plt.xlabel('article channel: social media',size=11)
plt.xticks(size=11)
plt.yticks(size=11)
plt.semilogy()
plt.legend(loc=4)
txt = "This figure shows a correlation between number of shares and article channel(social media)"
plt.figtext(0.5, -0.11, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/socmed.png', format='png', bbox_inches="tight", dpi=300)

# %%
#6.Scatterplot for average_token_length (feature) vs. number of links (feature)
plt.rcParams["figure.figsize"] = (4,3)
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(df['average_token_length'],df['num_hrefs'], alpha=0.8, s = 5)
plt.ylabel('number of links',size=11)
plt.xlabel('average token length',size=11)
plt.xticks(size=11)
plt.yticks(size=11)

txt = "This figure shows a correlation between number of links and average token length"
plt.figtext(0.5, -0.11, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/ftr1.png', format='png', bbox_inches="tight", dpi=300)
plt.show()

# %%
#7. Category-specific histograms for LDA_02 and data_channel_is_world
plt.rcParams["figure.figsize"] = (4,3)
plt.rcParams['axes.facecolor'] = 'white'
categories = df['data_channel_is_world'].unique()
bin_range = (df['LDA_02'].min(),df['LDA_02'].max())

for c in categories:
        plt.hist(df[df['data_channel_is_world']==c]['LDA_02'],alpha=0.5,label=c, range=bin_range, bins=10, density=True)

plt.legend()
plt.ylabel('counts', size=11)
plt.xlabel('closeness to LDA topic 2',size=11)
plt.xticks(size=11)
plt.yticks(size=11)
plt.semilogy()
txt = "This figure shows a correlation between world channel and closeness to LDA topic 2"
plt.figtext(0.5, -0.11, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/ftr2.png', format='png', bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# Part II: Data Preprocessing

# %% [markdown]
# 1). Data Split:
# Since the online news information from this dataset is all collected from Mashable(www.mashable.com) and each of them are independent from the others. The dataset does not have any group structures and time-series data. Thus, it is an iid dataset. I would conduct KFold splitting method.

# %%
df = df.groupby('shares', group_keys=False).apply(lambda x: x.sample(frac=0.3))
df.shape
# Out:
# (11894, 56)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
random_state =42

X=df.drop(columns=['shares'])
y=df['shares']

# first split to separate out the test set
X_other, X_test, y_other, y_test = train_test_split(X,y,test_size = 0.2,random_state=random_state)
print('   test set:',X_test.shape,y_test.shape)

# do KFold split on other
kf = KFold(n_splits=4,shuffle=True,random_state=random_state)
for train_index, val_index in kf.split(X_other,y_other):
    X_train = X_other.iloc[train_index]
    y_train = y_other.iloc[train_index]
    X_val = X_other.iloc[val_index]
    y_val = y_other.iloc[val_index]
    print('   training set:',X_train.shape, y_train.shape) 
    print('   validation set:',X_val.shape, y_val.shape)
# Out:
#    test set: (2379, 55) (2379,)
#    training set: (7136, 55) (7136,)
#    validation set: (2379, 55) (2379,)
#    training set: (7136, 55) (7136,)
#    validation set: (2379, 55) (2379,)
#    training set: (7136, 55) (7136,)
#    validation set: (2379, 55) (2379,)
#    training set: (7137, 55) (7137,)
#    validation set: (2378, 55) (2378,)

# %%
#find the missing value
print("missing values in features:\n", df.isnull().sum())
# Out:
# missing values in features:
#  n_tokens_title                   0
# n_tokens_content                 0
# n_unique_tokens                  0
# num_hrefs                        0
# num_self_hrefs                   0
# num_imgs                         0
# num_videos                       0
# average_token_length             0
# num_keywords                     0
# data_channel_is_lifestyle        0
# data_channel_is_entertainment    0
# data_channel_is_bus              0
# data_channel_is_socmed           0
# data_channel_is_tech             0
# data_channel_is_world            0
# kw_min_min                       0
# kw_avg_min                       0
# kw_min_max                       0
# kw_max_max                       0
# kw_avg_max                       0
# kw_min_avg                       0
# kw_max_avg                       0
# kw_avg_avg                       0
# self_reference_min_shares        0
# self_reference_max_shares        0
# self_reference_avg_sharess       0
# ...

# %% [markdown]
# There is no missing value in this dataset, so we don't have to deal with sort of problem.

# %%
#for classification problem, we use f_classif, mutual_info_classif
from sklearn.feature_selection import f_classif, mutual_info_classif

np.random.seed(10)

#caculate f_test for each feature
X=df.drop(columns=['shares'])
y=df['shares']
f_test, p_values = f_classif(X,y)
mi = mutual_info_classif(X,y)

for i in range(len(X_train.columns)):
    print('Linear F_score: ' + X_train.columns[i], f_test[i])

#plot the top 5 most important five feature (linear)
df_ftest={'name':X.columns,"f":f_test}
df_ftest=pd.DataFrame(df_ftest)
plt.figure(figsize=(10,6))
best_value = df_ftest.sort_values(by = 'f', ascending = False).head(5) 
plt.bar(best_value['name'],best_value['f'])
plt.ylabel('f_score', size=11)
plt.xlabel('feature name',size=11)
plt.xticks(size=11)
plt.yticks(size=11)
txt = "This figure shows the f_scores for 5 best features"
plt.figtext(0.5, -0.01, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/f_test.png', format='png', bbox_inches="tight", dpi=300)
plt.show()
# Out:
# Linear F_score: n_tokens_title 16.945394567207604
# Linear F_score: n_tokens_content 7.66076876251132
# Linear F_score: n_unique_tokens 21.110963420313247
# Linear F_score: num_hrefs 97.52915623542667
# Linear F_score: num_self_hrefs 14.728151379414962
# Linear F_score: num_imgs 47.21576643410992
# Linear F_score: num_videos 1.1385007480458915
# Linear F_score: average_token_length 16.151528518525616
# Linear F_score: num_keywords 61.568012510026115
# Linear F_score: data_channel_is_lifestyle 12.606375631961539
# Linear F_score: data_channel_is_entertainment 129.61190077916856
# Linear F_score: data_channel_is_bus 0.12481522693497053
# Linear F_score: data_channel_is_socmed 118.84790154434931
# Linear F_score: data_channel_is_tech 120.7464267992231
# Linear F_score: data_channel_is_world 301.4173400475807
# Linear F_score: kw_min_min 53.93146546775102
# Linear F_score: kw_avg_min 11.531599845907605
# Linear F_score: kw_min_max 0.16064317439724113
# ...

# %%
#caculate the mi score for each features
for i in range(len(X_train.columns)):
    print('Non-Linear mi_score:',X_train.columns[i], mi[i])

#plot the top five important feature (non-linear)
df_mtest={'name':X.columns,"mi":mi}
df_mtest=pd.DataFrame(df_mtest)
plt.figure(figsize=(12,6))
best_value = df_mtest.sort_values(by = 'mi', ascending = False).head(5) 
plt.bar(best_value['name'],best_value['mi'])
plt.ylabel('mi_score',size=11)
plt.xlabel('feature name',size=11)
plt.xticks(size=11)
plt.yticks(size=11)
txt = "This figure shows the mi score for 5 best features"
plt.figtext(0.5, -0.01, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/mi.png', format='png', bbox_inches="tight", dpi=300)
plt.show()
# Out:
# Non-Linear mi_score: n_tokens_title 0.0012106366190485218
# Non-Linear mi_score: n_tokens_content 0.0
# Non-Linear mi_score: n_unique_tokens 0.0
# Non-Linear mi_score: num_hrefs 0.003240900246109568
# Non-Linear mi_score: num_self_hrefs 0.009311960787787177
# Non-Linear mi_score: num_imgs 0.000520450746312795
# Non-Linear mi_score: num_videos 0.006464976379599197
# Non-Linear mi_score: average_token_length 0.004764381395016448
# Non-Linear mi_score: num_keywords 0.009658800112649857
# Non-Linear mi_score: data_channel_is_lifestyle 0.0
# Non-Linear mi_score: data_channel_is_entertainment 0.004050465852537988
# Non-Linear mi_score: data_channel_is_bus 0.0007090847598256733
# Non-Linear mi_score: data_channel_is_socmed 0.009204541518952114
# Non-Linear mi_score: data_channel_is_tech 0.0012555780616028134
# Non-Linear mi_score: data_channel_is_world 0.016886951507340653
# Non-Linear mi_score: kw_min_min 0.0
# Non-Linear mi_score: kw_avg_min 0.009314873941472346
# ...

# %% [markdown]
# # Define a function for running ML models

# %%
#define the function for training models
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler, LabelEncoder
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.pipeline import Pipeline

import pandas as pd
import warnings
warnings.filterwarnings("ignore")

def MLpipe_KFold_Acc(X, y, preprocessor, ML_algo, param_grid):

    nr_states = 10
    test_scores = np.zeros(nr_states)
    final_models = []

    for i in range(nr_states):
        # first split to separate out the test set
        # we will use kfold on other
        random_state=42*i
        X_other, X_test, y_other, y_test = train_test_split(X,y,test_size = 0.2,random_state=random_state)
      

        # splitter for other
        kf = KFold(n_splits=4,shuffle=True,random_state=random_state)
        clf = ML_algo
        
        #create pipe
        pipe = make_pipeline(preprocessor, clf)
        #pipe = Pipeline(steps=[('preprocess', preprocessor),('model', model)])

        # use GridSearchCV
        # GridSearchCV loops through all parameter combinations and collects the results 
        grid = GridSearchCV(pipe, param_grid=param_grid, scoring = 'accuracy',
                            cv=kf, return_train_score = True, n_jobs=-1, verbose=True)

        # this line actually fits the model on other
        grid.fit(X_other, y_other)
        # save results into a data frame. feel free to print it and inspect it
        results = pd.DataFrame(grid.cv_results_)
        #print(results)
        best_params = grid.best_params_
        best_score = grid.best_score_
        
        print('best model parameters:',grid.best_params_)
        print('validation score:',grid.best_score_) # this is the mean validation score over all iterations
        # save the model
        final_models.append(grid)
        # calculate and save the test score
        y_test_pred = final_models[-1].predict(X_test)
        test_scores[i] = accuracy_score(y_test,y_test_pred)
        print('test score:',test_scores[i])
    
    return final_models, test_scores

# %% [markdown]
# Since the original dataset has already encoder categorical variables (columns relates to "post date" and 'channel type" using OneHotEncoder, and all the of the columns are numerical values, we should only need to preprocessing the continuous data with StandardScaler and MinMaxScaler method.
# For the continuous data which has clear bound, such as the 'rate' columns and the columns related to NLP information, which normally have bound from (-1,0), (1,0) or (-1,1), I would us MinMaxSclaer preprocessor.
# For the rest, I would use StandardScaler preprocessor to process.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# standardscaler feature

std_ftrs = ['n_tokens_title', 'n_tokens_content', 'n_unique_tokens', 
            'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos', 'average_token_length', 'num_keywords', 
            'kw_min_min', 'kw_avg_min', 'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 
            'kw_max_avg', 'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares', 
            'self_reference_avg_sharess']

#minmaxscaler feature 
minmax_ftrs = ['global_rate_positive_words', 'global_rate_negative_words', 'rate_positive_words', 
               'rate_negative_words', 'LDA_00', 'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 
            'global_subjectivity', 'global_sentiment_polarity','avg_positive_polarity','min_positive_polarity', 
            'max_positive_polarity', 'avg_negative_polarity', 'min_negative_polarity', 'max_negative_polarity', 
            'title_subjectivity','title_sentiment_polarity', 'abs_title_subjectivity', 'abs_title_sentiment_polarity']

# standard scaler
std_transformer = Pipeline(steps=[('std', StandardScaler())])

# minmax encoder
minmax_transformer = Pipeline(steps=[('minmax', MinMaxScaler())])

# collect the transformers
preprocessor = ColumnTransformer(
    transformers=[('std', std_transformer, std_ftrs),
                 ('minmax', minmax_transformer, minmax_ftrs)])

# %% [markdown]
# # Logistic Regression

# %%
#run model
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
X=df.drop(columns=['shares'])
y=df['shares']

ML_algo = LogisticRegression(max_iter = 1000000)
param_grid = {'logisticregression__C': [100, 10, 1.0, 0.1, 0.01]}

final_models, test_scores = MLpipe_KFold_Acc(X, y, preprocessor = preprocessor, ML_algo = ML_algo, param_grid = param_grid)

mean_score = []
std_score = []
label = []
mean_score.append(np.mean(test_scores))
std_score.append(np.std(test_scores))
label.append('Logistic_Regression')

print('the mean of (LR) test scores:', np.mean(test_scores))
print('the std of (LR) test scores:', np.std(test_scores))
# Out:
# Fitting 4 folds for each of 5 candidates, totalling 20 fits
# best model parameters: {'logisticregression__C': 0.1}
# validation score: 0.6302686706042605
# test score: 0.6254728877679697
# Fitting 4 folds for each of 5 candidates, totalling 20 fits
# best model parameters: {'logisticregression__C': 100}
# validation score: 0.6303734032470125
# test score: 0.6305170239596469
# Fitting 4 folds for each of 5 candidates, totalling 20 fits
# best model parameters: {'logisticregression__C': 0.1}
# validation score: 0.6310046715177766
# test score: 0.6208490962589324
# Fitting 4 folds for each of 5 candidates, totalling 20 fits
# best model parameters: {'logisticregression__C': 0.1}
# validation score: 0.6305821172857118
# test score: 0.617906683480454
# Fitting 4 folds for each of 5 candidates, totalling 20 fits
# best model parameters: {'logisticregression__C': 1.0}
# validation score: 0.6305833104424012
# test score: 0.6229508196721312
# ...

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

ML_algo = RandomForestClassifier(random_state=42*i)
param_grid = {'randomforestclassifier__max_depth': [1, 3, 10, 30, 100],
              'randomforestclassifier__max_features': [0.25,0.5,0.75,1.0]}

final_models, test_scores = MLpipe_KFold_Acc(X, y, preprocessor = preprocessor, ML_algo = ML_algo, param_grid = param_grid)

mean_score.append(np.mean(test_scores))
std_score.append(np.std(test_scores))
label.append('Random_Forest')

print('the mean of (RF) test scores:', np.mean(test_scores))
print('the std of (RF) test scores:', np.std(test_scores))
# Out:
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# best model parameters: {'randomforestclassifier__max_depth': 10, 'randomforestclassifier__max_features': 1.0}
# validation score: 0.6414089536599153
# test score: 0.6456494325346784
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# best model parameters: {'randomforestclassifier__max_depth': 10, 'randomforestclassifier__max_features': 0.25}
# validation score: 0.6428795413753154
# test score: 0.6401849516603615
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# best model parameters: {'randomforestclassifier__max_depth': 10, 'randomforestclassifier__max_features': 0.75}
# validation score: 0.64750518890587
# test score: 0.6380832282471627
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# best model parameters: {'randomforestclassifier__max_depth': 100, 'randomforestclassifier__max_features': 0.75}
# validation score: 0.6434039558358796
# test score: 0.6359815048339639
# ...

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

ML_algo = SVC()
param_grid = {'svc__C': [0.1, 1, 10, 100, 1000], 
              'svc__gamma': [1, 0.1, 0.01, 0.001, 0.0001]}

final_models, test_scores = MLpipe_KFold_Acc(X, y, preprocessor = preprocessor, ML_algo = ML_algo, param_grid = param_grid)

mean_score.append(np.mean(test_scores))
std_score.append(np.std(test_scores))
label.append('SVC')

print('the mean of (SVC) test scores:', np.mean(test_scores))
print('the std of (SVC) test scores:', np.std(test_scores))
# Out:
# Fitting 4 folds for each of 25 candidates, totalling 100 fits
# best model parameters: {'svc__C': 100, 'svc__gamma': 0.001}
# validation score: 0.6326856525294392
# test score: 0.6334594367381252
# Fitting 4 folds for each of 25 candidates, totalling 100 fits
# best model parameters: {'svc__C': 1000, 'svc__gamma': 0.001}
# validation score: 0.63373647004505
# test score: 0.6422866750735603
# Fitting 4 folds for each of 25 candidates, totalling 100 fits
# best model parameters: {'svc__C': 10, 'svc__gamma': 0.01}
# validation score: 0.63668060627208
# test score: 0.6326187473728457
# Fitting 4 folds for each of 25 candidates, totalling 100 fits
# best model parameters: {'svc__C': 100, 'svc__gamma': 0.001}
# validation score: 0.6383592893523404
# test score: 0.6208490962589324
# Fitting 4 folds for each of 25 candidates, totalling 100 fits
# best model parameters: {'svc__C': 100, 'svc__gamma': 0.001}
# validation score: 0.6363641987943991
# test score: 0.6284153005464481
# ...

# %% [markdown]
# # KNN

# %%
import warnings 
warnings.filterwarnings("ignore")
import numpy as np
from scipy.stats import mode
from sklearn.neighbors import KNeighborsClassifier

ML_algo = KNeighborsClassifier()
param_grid = {'kneighborsclassifier__n_neighbors': [1,10,30,50,80,100]}

final_models, test_scores = MLpipe_KFold_Acc(X, y, preprocessor = preprocessor, ML_algo = ML_algo, param_grid = param_grid)

mean_score.append(np.mean(test_scores))
std_score.append(np.std(test_scores))
label.append('KNN')

print('the mean of (KNN) test scores:', np.mean(test_scores))
print('the std of (KNN) test scores:', np.std(test_scores))
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# /Users/qinmiaodeng/opt/anaconda3/envs/env/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# # XGBoost

# %%
import xgboost
nr_states = 10
test_scores = np.zeros(nr_states)
final_models = []

for i in range(nr_states):
    # first split to separate out the test set
    # we will use kfold on other
    random_state=42*i
    X_other, X_test, y_other, y_test = train_test_split(X,y,test_size = 0.2,random_state=random_state)
    # splitter for other
    kf = KFold(n_splits=4,shuffle=True,random_state=random_state)
    for train_index, val_index in kf.split(X_other, y_other):
        X_train = X_other.iloc[train_index]
        y_train = y_other.iloc[train_index]
        X_val = X_other.iloc[val_index]
        y_val = y_other.iloc[val_index]

    # fit_transform the training set
    X_prep = preprocessor.fit_transform(X_train)
    # collect feature names
    feature_names = preprocessor.get_feature_names_out()
    df_train = pd.DataFrame(data=X_prep,columns=feature_names)
    # transform the CV
    df_val = preprocessor.transform(X_val)
    df_val = pd.DataFrame(data=df_val,columns = feature_names)
    # transform the test
    df_test = preprocessor.transform(X_test)
    df_test = pd.DataFrame(data=df_test,columns = feature_names)

    y_train = np.reshape(np.array(y_train), (1, -1)).ravel()
    y_val = np.reshape(np.array(y_val), (1, -1)).ravel()
    y_test = np.reshape(np.array(y_test), (1, -1)).ravel()
    #param_grid -- tune the learning_rate
    param_grid = {"learning_rate": [0.0001, 0.001, 0.01, 0.1],
                  "n_estimators": [1,10,100,1000],
                  "max_depth": [1,3,10,30,100]
                  #"seed": [0],
                  #"reg_alpha": [0e0, 1e-2, 1e-1, 1e0, 1e1, 1e2], 
                  #"reg_lambda": [0e0, 1e-2, 1e-1, 1e0, 1e1, 1e2], "missing": [np.nan],
                  #"colsample_bytree": [0.9],"subsample": [0.66]
                 }

    #save the results
    models = []
    train_score = np.zeros(len(ParameterGrid(param_grid)))
    val_score = np.zeros(len(ParameterGrid(param_grid)))

    for p in range(len(ParameterGrid(param_grid))): 
        params = ParameterGrid(param_grid)[p]
        XGB = xgboost.XGBClassifier(**params)
        XGB.fit(df_train,y_train,early_stopping_rounds=50,eval_set=[(df_val, y_val)], 
                    verbose=False,eval_metric='logloss')
        models.append(XGB)
        y_train_pred = XGB.predict(df_train)
        train_score[p] = accuracy_score(y_train,y_train_pred)
        y_val_pred = XGB.predict(df_val)
        val_score[p] = accuracy_score(y_val,y_val_pred)

    #caculate the accuracy score
    final_models.append(models[np.argmax(val_score)])
    y_test_pred = final_models[-1].predict(df_test)
    test_scores[i] = accuracy_score(y_test,y_test_pred)

    #save the test sets
    print('test score:', test_scores[i])
    print('best model:', final_models[i])

#save the test scores
mean_score.append(np.mean(test_scores))
std_score.append(np.std(test_scores))
label.append('XGBoost')

print('the mean(XGBoost) of test score:', np.mean(test_scores))
print('the standard deviation(XGBoost) of test score:', np.std(test_scores))
# Out:
# test score: 0.6385035729298024
# best model: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=3, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
# test score: 0.6292559899117276
# best model: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
# ...

# %%
final_models[-1]
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#               max_depth=3, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=1000, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
#mean_score[-2], mean_score[-1] = mean_score[-1], mean_score[-2]
print('mean score:',mean_score)
print('std score:', std_score)
print(label)
# Out:
# mean score: [0.6281210592686003, 0.6418663303909204, 0.633921815889029, 0.6129886506935687, 0.6443463640184952]
# std score: [0.006380522139200065, 0.004480172373089277, 0.007846946979773464, 0.006932629537291103, 0.010942614423224483]
# ['Logistic_Regression', 'Random_Forest', 'SVC', 'KNN', 'XGBoost']

# %%
#baseline accuracy score

# %% [markdown]
# The baseline accuracy score is the percentage of our marjority class, which 50% accuracy score.

# %% [markdown]
# # summarize the results

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10,5]
plt.errorbar(label, mean_score, yerr=std_score, fmt='go', ecolor='orange', capsize=5)
plt.xlabPel('Models',size=11)
plt.ylabel('test score of different models',size=11)
plt.xticks(size=11)
plt.yticks(size=11)
plt.title('Error Bar for each model\'s test score',size=11)
txt = "This figure shows both the mean and std of each model's accuracy score"
plt.figtext(0.5, -0.03, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/model_performance.png', format='png', bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# Here we select XGBoost as our final best model, with test score 0.35813366960907944.

# %%
final_test_score = mean_score[1]
final_test_score
# Out:
# 0.6418663303909204

# %% [markdown]
# # Confusion Matrix

# %%
import matplotlib
from matplotlib import pylab as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

print('The confusion matrix is:')
print(confusion_matrix(y_test,y_test_pred))
cm = confusion_matrix(y_test,y_test_pred)
disp = ConfusionMatrixDisplay(cm,display_labels=['class 0', 'class 1'])
disp.plot()
plt.xlabel('Predicted label',size=11)
plt.ylabel('True label',size=11)
plt.xticks(size=11)
plt.yticks(size=11)
plt.tight_layout()
plt.title('confusion matrix', size=11)
txt = "This figure shows the confusion matrix of y_true and y_pred"
plt.figtext(0.5, -0.03, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/confusion_matrix.png', format='png', bbox_inches="tight", dpi=500)
plt.show()
# Out:
# The confusion matrix is:
# [[791 415]
#  [396 777]]

# %%
#recall score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
print('accuracy score:', accuracy_score(y_test, y_test_pred))
print('recall score:', recall_score(y_test, y_test_pred))
print('precision score:', precision_score(y_test, y_test_pred))
# Out:
# accuracy score: 0.6591004623791509
# recall score: 0.6624040920716112
# precision score: 0.6518456375838926

# %% [markdown]
# # Feature Importance

# %% [markdown]
# global importance

# %% [markdown]
# 1.permutation importance

# %%
nr_runs = 10
scores = np.zeros([len(feature_names),nr_runs])
# loop through the features
print('test score =', final_test_score)
for i in range(len(feature_names)): 
    print('shuffling '+str(feature_names[i])) 
    acc_scores = []
    for j in range(nr_runs):
        X_test_shuffled = df_test.copy()
        X_test_shuffled[feature_names[i]] = np.random.permutation(df_test[feature_names[i]].values) 
        acc_scores.append(XGB.score(X_test_shuffled,y_test))
    print(' shuffled test score:',np.around(np.mean(acc_scores),3),'+/-',np.around(np.std(acc_scores),3)) 
    scores[i] = acc_scores
# Out:
# test score = 0.6418663303909204
# shuffling std__n_tokens_title
#  shuffled test score: 0.624 +/- 0.001
# shuffling std__n_tokens_content
#  shuffled test score: 0.621 +/- 0.003
# shuffling std__n_unique_tokens
#  shuffled test score: 0.616 +/- 0.003
# shuffling std__num_hrefs
#  shuffled test score: 0.614 +/- 0.004
# shuffling std__num_self_hrefs
#  shuffled test score: 0.617 +/- 0.003
# shuffling std__num_imgs
#  shuffled test score: 0.619 +/- 0.002
# shuffling std__num_videos
#  shuffled test score: 0.623 +/- 0.001
# shuffling std__average_token_length
#  shuffled test score: 0.622 +/- 0.003
# shuffling std__num_keywords
#  shuffled test score: 0.624 +/- 0.001
# shuffling std__kw_min_min
#  shuffled test score: 0.621 +/- 0.001
# shuffling std__kw_avg_min
#  shuffled test score: 0.62 +/- 0.004
# shuffling std__kw_min_max
#  shuffled test score: 0.616 +/- 0.004
# shuffling std__kw_max_max
#  shuffled test score: 0.62 +/- 0.005
# shuffling std__kw_avg_max
# ...

# %%
#plot the top 10 features
sorted_indcs = np.argsort(np.mean(scores,axis=1))[:10][::-1]
plt.rcParams.update({'font.size': 13})
plt.figure(figsize=(7,5)) 
plt.boxplot(scores[sorted_indcs].T,labels=feature_names[sorted_indcs],vert=False) 
plt.axvline(final_test_score, label='test score')
plt.xlabel('score with perturbed feature', size=11)
plt.title('permutation feature importance', size=11)
plt.legend()
plt.tight_layout()
plt.xticks(size=11)
plt.yticks(size=11)
txt = "This figure shows top 10 permutation feature importance "
plt.figtext(0.5, 0.01, txt, ha='center', size=11)
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/permutation_importance.png', format='png', bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# 2. XGBoost importance

# %%
    #weight method
    ftr_score=XGB.get_booster().get_score(fmap='', importance_type = 'weight') 
    ftr_s = list(ftr_score.items())
    df_ftr = pd.DataFrame(ftr_s, columns=['feature_name', 'score']) 
    df_ftr = df_ftr.sort_values(by=['score'],ascending=False).head(10) 
    print("top 10 important feature measured by method 'weight'" )
    print(df_ftr)
    
    plt.barh(df_ftr['feature_name'], df_ftr['score'], color ='wheat') 
    plt.xlabel('scores',size=11)
    plt.ylabel('top 10 features',size=11)
    plt.xticks(size=11)
    plt.yticks(size=11)
    plt.title("XGBoost feature importance by method weight",size=11)
    txt = "This figure shows top 10 most important features measured by method weight" 
    plt.figtext(0.5, -0.03, txt, ha='center',size=11)
    rc('font',**{'family':'serif','serif':['Times']})
    rc('text', usetex=True)
    plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/XGB_weight.png', format='png', bbox_inches="tight", dpi=300)
    plt.show()
# Out:
# top 10 important feature measured by method 'weight'
#                           feature_name   score
# 10                     std__kw_avg_min  1363.0
# 15                     std__kw_max_avg  1322.0
# 16                     std__kw_avg_avg  1292.0
# 13                     std__kw_avg_max  1269.0
# 28                      minmax__LDA_04  1229.0
# 7            std__average_token_length  1225.0
# 29         minmax__global_subjectivity  1194.0
# 20  minmax__global_rate_positive_words  1189.0
# 26                      minmax__LDA_02  1188.0
# 24                      minmax__LDA_00  1173.0

# %%
    ftr_score=XGB.get_booster().get_score(fmap='', importance_type = 'gain') 
    ftr_s = list(ftr_score.items())
    df_ftr = pd.DataFrame(ftr_s, columns=['feature_name', 'score']) 
    df_ftr = df_ftr.sort_values(by=['score'],ascending=False).head(10) 
    print('top 10 important feature measured by method gain')
    print(df_ftr)
    
    plt.barh(df_ftr['feature_name'], df_ftr['score'], color ='wheat') 
    plt.xlabel('scores',size=11)
    plt.ylabel('top 10 features',size=11)
    plt.xticks(size=11)
    plt.yticks(size=11)
    plt.title("XGBoost feature importance by method gain",size=11)
    txt = "This figure shows top 10 most important features measured by method gain" 
    plt.figtext(0.5, -0.03, txt, ha='center',size=11)
    rc('font',**{'family':'serif','serif':['Times']})
    rc('text', usetex=True)
    plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/XGB_gain.png', format='png', bbox_inches="tight", dpi=300)
    plt.show()
# Out:
# top 10 important feature measured by method gain
#                        feature_name     score
# 12                  std__kw_max_max  4.349381
# 16                  std__kw_avg_avg  2.783620
# 19  std__self_reference_avg_sharess  2.403570
# 17   std__self_reference_min_shares  1.766205
# 23      minmax__rate_negative_words  1.633531
# 15                  std__kw_max_avg  1.607414
# 32    minmax__min_positive_polarity  1.594491
# 28                   minmax__LDA_04  1.570901
# 11                  std__kw_min_max  1.562467
# 24                   minmax__LDA_00  1.523101

# %%
    #method cover
    ftr_score=XGB.get_booster().get_score(fmap='', importance_type = 'cover') 
    ftr_s = list(ftr_score.items())
    df_ftr = pd.DataFrame(ftr_s, columns=['feature_name', 'score']) 
    df_ftr = df_ftr.sort_values(by=['score'],ascending = False).head(10) 
    print('top 10 important feature measured by method cover' )
    print(df_ftr)
    
    plt.barh(df_ftr['feature_name'], df_ftr['score'], color ='wheat') 
    plt.xlabel('scores',size=11)
    plt.ylabel('top 10 features',size=11)
    plt.xticks(size=11)
    plt.yticks(size=11)
    plt.title("XGBoost feature importance by method cover",size=11)
    txt = "This figure shows top 10 most important features measured by method cover" 
    plt.figtext(0.5, -0.03, txt, ha='center',size=11)
    rc('font',**{'family':'serif','serif':['Times']})
    rc('text', usetex=True)
    plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/XGB_cover.png', format='png', bbox_inches="tight", dpi=300)
    plt.show()
# Out:
# top 10 important feature measured by method cover
#                        feature_name       score
# 12                  std__kw_max_max  116.335098
# 23      minmax__rate_negative_words   57.842999
# 19  std__self_reference_avg_sharess   53.775848
# 16                  std__kw_avg_avg   47.360157
# 17   std__self_reference_min_shares   40.840576
# 32    minmax__min_positive_polarity   34.733799
# 11                  std__kw_min_max   31.577848
# 15                  std__kw_max_avg   29.201246
# 14                  std__kw_min_avg   28.666557
# 28                   minmax__LDA_04   28.275642

# %% [markdown]
# 3. Shap importance

# %%
import shap
shap.initjs() # required for visualizations later on
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(df_test)
shap.summary_plot(shap_values, df_test, feature_names = feature_names, max_display = 10)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
plt.savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/global_shap.png', format='png', bbox_inches="tight", dpi=300)

# %%
i = 4
print('4th observation')
shap.force_plot(explainer.expected_value, shap_values[i,:], features=df_test.iloc[i,:], feature_names=df_test.columns)
# Out:
# 4th observation
# <div id='i3E6HDF4U5W4GPLF4NRDO'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
print(y_test[4])
print(y_test_pred[4])
# Out:
# 0
# 0

# %%
shap.force_plot(explainer.expected_value, shap_values[i], features=df_test.iloc[i], feature_names=df_test.columns, show=False,matplotlib=True).savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/local_shap_4th.png', format='png', bbox_inches="tight", dpi=300)

# %%
i = 100
print('100th observation')
shap.force_plot(explainer.expected_value, shap_values[i,:], features=df_test.iloc[i,:], feature_names=df_test.columns)
# Out:
# 100th observation
# <div id='i2SQ6FFO1OTURDRBEZ4XZ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
print(y_test[100])
print(y_test_pred[100])
# Out:
# 0
# 0

# %%
shap.force_plot(explainer.expected_value, shap_values[i], features=df_test.iloc[i],feature_names=df_test.columns,show = False, matplotlib=True).savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/local_shap_100th.png', format='png', bbox_inches='tight',dpi=300)

# %%
i = 224
print('224th observation ')
shap.force_plot(explainer.expected_value, shap_values[i,:], features=df_test.iloc[i,:], feature_names=df_test.columns)
# Out:
# 224th observation
# <div id='iB11QU4VF7GKK6DY15HSQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.force_plot(explainer.expected_value, shap_values[i], features=df_test.iloc[i], feature_names=df_test.columns,show = False, matplotlib=True).savefig('/Users/qinmiaodeng/Desktop/DATA1030-Fall2022/Data1030-Project/fig/local_shap_224th.png', format='png', bbox_inches='tight',dpi=300)

# %%
print(y_test[224])
print(y_test_pred[224])
# Out:
# 0
# 0

# %%
i = 87
print('224th observation ')
shap.force_plot(explainer.expected_value, shap_values[i,:], features=df_test.iloc[i,:], feature_names=df_test.columns)
# Out:
# 224th observation
# <div id='i7N7C4K844RVZIYCV4WTV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
y_test[87]
y_test_pred[87]
# Out:
# 1
